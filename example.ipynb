# %%
from dag import DAG
import os

# %%
d = DAG([(0, 1),(1,1),(2,3),(1,3)])
d._draw()
d.serialize()

# %%
dd = DAG.deserialize(os.path.join(os.getcwd(),'graph-dump.hdf5'))

# %%
dd.save_graph_to_png()

# %%
dd.save_histogram_to_png()
